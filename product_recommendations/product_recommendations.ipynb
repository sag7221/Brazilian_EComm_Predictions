# %%
# importing necessary Python libraries
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import plotly.express as px
#import plotly.offline as pyoff
import plotly.graph_objs as go 
#import plotly.figure_factory as ff

# avoid displaying warnings
import warnings
warnings.filterwarnings("ignore")

#import machine learning related libraries
import time

# %%
# Loading the data
# We are going to do product related categorization and/or predictions
# For this we need : Customers table, Orders table, Order_Items table, Products table, Product translation table
customers_df = pd.read_csv('Resources/olist_customers_dataset.csv')
orders_df = pd.read_csv('Resources/olist_orders_dataset.csv')
order_items_df = pd.read_csv('Resources/olist_order_items_dataset.csv')
products_df = pd.read_csv('Resources/olist_products_dataset.csv')
products_translation_df = pd.read_csv('Resources/product_category_name_translation.csv')
order_payments_df = pd.read_csv('Resources/olist_order_payments_dataset.csv')
reviews_df = pd.read_csv('Resources/olist_order_reviews_dataset.csv')

# %% [markdown]
# **Merging the following csvs**
# 1. Both products related csvs to get one products table
# 2. Merge products table with order_items on product_id
# 3. Merge order_items with orders to get customer_id
# 4. Merge with order_reviews to get review ratings
# 5. Lastly merge above with customers_df to get customers related info

# %%
products_combined_df = pd.merge(products_df, products_translation_df, on="product_category_name")
products_combined_df.head()
products_combined_df.drop("product_category_name", axis=1, inplace=True)
products_combined_df[['product_category_name_english']] = products_combined_df[['product_category_name_english']].astype(str)

# %% [markdown]
# **Merge with order_items_df**

# %%
pdts_items_df = pd.merge(products_combined_df, order_items_df, on="product_id")
pdts_items_df.head()
# Out:
#                          product_id  product_name_lenght  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5                 40.0
# 1  6a2fb4dd53d2cdb88e0432f1284a004c                 39.0
# 2  6a2fb4dd53d2cdb88e0432f1284a004c                 39.0
# 3  0d009643171aee696f4733340bc2fdd0                 52.0
# 4  0d009643171aee696f4733340bc2fdd0                 52.0
#
#    product_description_lenght  product_photos_qty  product_weight_g  \
# 0                       287.0                 1.0             225.0
# 1                       346.0                 2.0             400.0
# 2                       346.0                 2.0             400.0
# 3                       150.0                 1.0             422.0
# 4                       150.0                 1.0             422.0
#
#    product_length_cm  product_height_cm  product_width_cm  \
# 0               16.0               10.0              14.0
# 1               27.0                5.0              20.0
# 2               27.0                5.0              20.0
# 3               21.0               16.0              18.0
# 4               21.0               16.0              18.0
#
#   product_category_name_english                          order_id  \
# 0                     perfumery  e17e4f88e31525f7deef66779844ddce
# 1                     perfumery  048cc42e03ca8d43c729adf6962cb348
# 2                     perfumery  5fa78e91b5cb84b6a8ccc42733f95742
# 3                     perfumery  24b1c4d88fdb7a2dc87f8ecc7d8f47f1
# 4                     perfumery  7b13c77c64a9a956500cbf1a9a23798d
#
#    order_item_id                         seller_id  shipping_limit_date  \
# 0              1  5670f4db5b62c43d542e1b2d56b0cf7c  2018-04-30 17:33:54
# 1              1  7040e82f899a04d1b434b795a43b4617  2017-11-23 21:31:31
# 2              1  7040e82f899a04d1b434b795a43b4617  2017-12-14 16:33:14
# 3              1  fe2032dab1a61af8794248c8196565c9  2017-08-03 09:50:14
# 4              1  7178f9f4dd81dcef02f62acdf8151e01  2018-05-30 10:38:35
#
#     price  freight_value
# 0   10.91           7.39
# 1   16.90           7.78
# 2   16.90           7.78
# 3  339.00          17.13
# 4  275.00          23.48

# %% [markdown]
# **Merge items with reviews_df**

# %%
pdts_reviews_df = pd.merge(pdts_items_df, reviews_df, on="order_id")
pdts_reviews_df
# Out:
#                               product_id  product_name_lenght  \
# 0       1e9e8ef04dbcff4541ed26657ea517e5                 40.0
# 1       6a2fb4dd53d2cdb88e0432f1284a004c                 39.0
# 2       6a2fb4dd53d2cdb88e0432f1284a004c                 39.0
# 3       0d009643171aee696f4733340bc2fdd0                 52.0
# 4       0d009643171aee696f4733340bc2fdd0                 52.0
# ...                                  ...                  ...
# 110745  1dceebcc5f23c02ea23e16d5bedca000                 47.0
# 110746  1dceebcc5f23c02ea23e16d5bedca000                 47.0
# 110747  1dceebcc5f23c02ea23e16d5bedca000                 47.0
# 110748  1dceebcc5f23c02ea23e16d5bedca000                 47.0
# 110749  1dceebcc5f23c02ea23e16d5bedca000                 47.0
#
#         product_description_lenght  product_photos_qty  product_weight_g  \
# 0                            287.0                 1.0             225.0
# 1                            346.0                 2.0             400.0
# 2                            346.0                 2.0             400.0
# 3                            150.0                 1.0             422.0
# 4                            150.0                 1.0             422.0
# ...                            ...                 ...               ...
# 110745                       117.0                 2.0             550.0
# 110746                       117.0                 2.0             550.0
# 110747                       117.0                 2.0             550.0
# 110748                       117.0                 2.0             550.0
# 110749                       117.0                 2.0             550.0
#
#         product_length_cm  product_height_cm  product_width_cm  \
# 0                    16.0               10.0              14.0
# 1                    27.0                5.0              20.0
# 2                    27.0                5.0              20.0
# 3                    21.0               16.0              18.0
# 4                    21.0               16.0              18.0
# ...                   ...                ...               ...
# 110745               35.0               15.0              25.0
# 110746               35.0               15.0              25.0
# 110747               35.0               15.0              25.0
# 110748               35.0               15.0              25.0
# 110749               35.0               15.0              25.0
#
#        product_category_name_english                          order_id  ...  \
# 0                          perfumery  e17e4f88e31525f7deef66779844ddce  ...
# 1                          perfumery  048cc42e03ca8d43c729adf6962cb348  ...
# 2                          perfumery  5fa78e91b5cb84b6a8ccc42733f95742  ...
# 3                          perfumery  24b1c4d88fdb7a2dc87f8ecc7d8f47f1  ...
# 4                          perfumery  7b13c77c64a9a956500cbf1a9a23798d  ...
# ...                              ...                               ...  ...
# 110745             cds_dvds_musicals  7ed69fbc79fbda50e09caa9c127026e5  ...
# 110746             cds_dvds_musicals  9c782cb7854e5dfa91927cfca8949eb8  ...
# 110747             cds_dvds_musicals  cea54c1853c864ab36cea3ef732d7191  ...
# 110748             cds_dvds_musicals  d4e8d3bb5e3673ed68ac154fe86de946  ...
# 110749             cds_dvds_musicals  ffc4072a9ea36a3341efa25b69c449eb  ...
#
#                                seller_id  shipping_limit_date   price  \
# 0       5670f4db5b62c43d542e1b2d56b0cf7c  2018-04-30 17:33:54   10.91
# 1       7040e82f899a04d1b434b795a43b4617  2017-11-23 21:31:31   16.90
# 2       7040e82f899a04d1b434b795a43b4617  2017-12-14 16:33:14   16.90
# 3       fe2032dab1a61af8794248c8196565c9  2017-08-03 09:50:14  339.00
# 4       7178f9f4dd81dcef02f62acdf8151e01  2018-05-30 10:38:35  275.00
# ...                                  ...                  ...     ...
# 110745  4e922959ae960d389249c378d1c939f5  2018-05-02 11:54:43   65.00
# 110746  4e922959ae960d389249c378d1c939f5  2017-07-19 11:35:22   45.00
# 110747  4e922959ae960d389249c378d1c939f5  2017-11-14 11:50:17   65.00
# 110748  4e922959ae960d389249c378d1c939f5  2017-11-03 11:29:30   45.00
# 110749  4e922959ae960d389249c378d1c939f5  2017-11-27 18:31:18   65.00
#
#         freight_value                         review_id review_score  \
# 0                7.39  d71da8fd8c6e3adef26be965f065b8a1            5
# 1                7.78  0d953190c8ed55747f7b7ad3af2885e3            5
# 2                7.78  8e762254a11ad4292ec8fb6586c681cf            2
# 3               17.13  de311dfd0cf46c629921db407a7d87e9            5
# 4               23.48  097582b6b0630f5cb1a409c223c406dc            3
# ...               ...                               ...          ...
# 110745          52.58  fe178e554333a4aa1ebd413e67d1419f            5
# 110746          16.11  bc3edd7b44020db68f771461727308e7            5
# 110747           9.94  c264f18d933db39d774ec36addb9fd66            5
# 110748          16.11  d363709f221521f9a0e43945480e1ace            5
# 110749           9.94  d8fd951fdbe31fe1494300e3ac98c121            5
#
#          review_comment_title  \
# 0                Vale a pena
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4       Não passou confiança
# ...                       ...
# 110745                  OTIMO
# 110746                    NaN
# 110747                    NaN
# 110748                    NaN
# 110749                    NaN
#
#                                    review_comment_message  \
# 0       Super adooorei o delineador ele é bem preto e ...
# 1       O produto que chegou é mais bonito do que eu e...
# 2                                                     NaN
# 3       ótimo produto e ótima loja para comprar pelo s...
# 4       O fornecedor e a nf é de São Paulo, o produto ...
# ...                                                   ...
# 110745                                              OTIMO
# 110746                                                NaN
# 110747                                                NaN
# 110748                                                NaN
# 110749                             Boa loja recomendável
#
#        review_creation_date review_answer_timestamp
# 0       2018-04-28 00:00:00     2018-05-04 00:55:02
# 1       2017-11-24 00:00:00     2017-11-24 18:34:45
# 2       2017-12-14 00:00:00     2017-12-17 02:57:05
# 3       2017-08-09 00:00:00     2017-08-09 19:30:09
# 4       2018-06-07 00:00:00     2018-06-12 13:44:18
# ...                     ...                     ...
# 110745  2018-05-10 00:00:00     2018-05-11 13:58:25
# 110746  2017-07-19 00:00:00     2017-07-21 23:28:33
# 110747  2017-11-15 00:00:00     2017-11-16 11:26:14
# 110748  2017-11-04 00:00:00     2017-11-06 14:54:54
# 110749  2017-11-28 00:00:00     2017-11-28 18:15:47
#
# [110750 rows x 21 columns]

# %% [markdown]
# **Merge products_reviews with orders table**

# %%
pdts_orders_df = pd.merge(pdts_reviews_df, orders_df, on="order_id")
pdts_orders_df.head()
# Out:
#                          product_id  product_name_lenght  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5                 40.0
# 1  6a2fb4dd53d2cdb88e0432f1284a004c                 39.0
# 2  6a2fb4dd53d2cdb88e0432f1284a004c                 39.0
# 3  0d009643171aee696f4733340bc2fdd0                 52.0
# 4  0d009643171aee696f4733340bc2fdd0                 52.0
#
#    product_description_lenght  product_photos_qty  product_weight_g  \
# 0                       287.0                 1.0             225.0
# 1                       346.0                 2.0             400.0
# 2                       346.0                 2.0             400.0
# 3                       150.0                 1.0             422.0
# 4                       150.0                 1.0             422.0
#
#    product_length_cm  product_height_cm  product_width_cm  \
# 0               16.0               10.0              14.0
# 1               27.0                5.0              20.0
# 2               27.0                5.0              20.0
# 3               21.0               16.0              18.0
# 4               21.0               16.0              18.0
#
#   product_category_name_english                          order_id  ...  \
# 0                     perfumery  e17e4f88e31525f7deef66779844ddce  ...
# 1                     perfumery  048cc42e03ca8d43c729adf6962cb348  ...
# 2                     perfumery  5fa78e91b5cb84b6a8ccc42733f95742  ...
# 3                     perfumery  24b1c4d88fdb7a2dc87f8ecc7d8f47f1  ...
# 4                     perfumery  7b13c77c64a9a956500cbf1a9a23798d  ...
#
#                               review_comment_message review_creation_date  \
# 0  Super adooorei o delineador ele é bem preto e ...  2018-04-28 00:00:00
# 1  O produto que chegou é mais bonito do que eu e...  2017-11-24 00:00:00
# 2                                                NaN  2017-12-14 00:00:00
# 3  ótimo produto e ótima loja para comprar pelo s...  2017-08-09 00:00:00
# 4  O fornecedor e a nf é de São Paulo, o produto ...  2018-06-07 00:00:00
#
#   review_answer_timestamp                       customer_id  order_status  \
# 0     2018-05-04 00:55:02  f8a3e963a310aa58b60a5b1fed5bceb5     delivered
# 1     2017-11-24 18:34:45  12a2c614dfc8926e793516b1638c7471     delivered
# 2     2017-12-17 02:57:05  c15eed3881abc9e06763c989679c5094     delivered
# 3     2017-08-09 19:30:09  6d699e3ab0fd90fffb3d1379d937de77     delivered
# 4     2018-06-12 13:44:18  45d942b1af5529f8990f27848a40e645     delivered
#
#   order_purchase_timestamp    order_approved_at order_delivered_carrier_date  \
# 0      2018-04-24 16:16:53  2018-04-24 19:04:19          2018-04-25 17:01:00
# 1      2017-11-16 21:28:00  2017-11-17 21:35:39          2017-11-21 22:14:50
# 2      2017-11-30 01:51:23  2017-12-08 16:33:14          2017-12-09 00:53:08
# 3      2017-07-28 09:34:29  2017-07-28 09:50:14          2017-07-28 21:42:11
# 4      2018-05-17 09:24:18  2018-05-17 10:38:35          2018-06-01 09:04:00
#
#   order_delivered_customer_date order_estimated_delivery_date
# 0           2018-04-27 16:42:17           2018-05-09 00:00:00
# 1           2017-11-23 15:39:38           2017-11-29 00:00:00
# 2           2017-12-13 20:52:32           2017-12-18 00:00:00
# 3           2017-08-08 16:03:45           2017-08-21 00:00:00
# 4           2018-06-07 19:12:50           2018-06-05 00:00:00
#
# [5 rows x 28 columns]

# %% [markdown]
# **Merge above dataframe with customers table**

# %%
pdts_customers_df = pd.merge(pdts_orders_df, customers_df, on="customer_id")
pdts_customers_df.head()
# Out:
#                          product_id  product_name_lenght  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5                 40.0
# 1  6a2fb4dd53d2cdb88e0432f1284a004c                 39.0
# 2  6a2fb4dd53d2cdb88e0432f1284a004c                 39.0
# 3  0d009643171aee696f4733340bc2fdd0                 52.0
# 4  0d009643171aee696f4733340bc2fdd0                 52.0
#
#    product_description_lenght  product_photos_qty  product_weight_g  \
# 0                       287.0                 1.0             225.0
# 1                       346.0                 2.0             400.0
# 2                       346.0                 2.0             400.0
# 3                       150.0                 1.0             422.0
# 4                       150.0                 1.0             422.0
#
#    product_length_cm  product_height_cm  product_width_cm  \
# 0               16.0               10.0              14.0
# 1               27.0                5.0              20.0
# 2               27.0                5.0              20.0
# 3               21.0               16.0              18.0
# 4               21.0               16.0              18.0
#
#   product_category_name_english                          order_id  ...  \
# 0                     perfumery  e17e4f88e31525f7deef66779844ddce  ...
# 1                     perfumery  048cc42e03ca8d43c729adf6962cb348  ...
# 2                     perfumery  5fa78e91b5cb84b6a8ccc42733f95742  ...
# 3                     perfumery  24b1c4d88fdb7a2dc87f8ecc7d8f47f1  ...
# 4                     perfumery  7b13c77c64a9a956500cbf1a9a23798d  ...
#
#    order_status order_purchase_timestamp    order_approved_at  \
# 0     delivered      2018-04-24 16:16:53  2018-04-24 19:04:19
# 1     delivered      2017-11-16 21:28:00  2017-11-17 21:35:39
# 2     delivered      2017-11-30 01:51:23  2017-12-08 16:33:14
# 3     delivered      2017-07-28 09:34:29  2017-07-28 09:50:14
# 4     delivered      2018-05-17 09:24:18  2018-05-17 10:38:35
#
#    order_delivered_carrier_date  order_delivered_customer_date  \
# 0           2018-04-25 17:01:00            2018-04-27 16:42:17
# 1           2017-11-21 22:14:50            2017-11-23 15:39:38
# 2           2017-12-09 00:53:08            2017-12-13 20:52:32
# 3           2017-07-28 21:42:11            2017-08-08 16:03:45
# 4           2018-06-01 09:04:00            2018-06-07 19:12:50
#
#   order_estimated_delivery_date                customer_unique_id  \
# 0           2018-05-09 00:00:00  b1a1199364a4a7fe27c4486ab63f550d
# 1           2017-11-29 00:00:00  7139ee1d2ad919a82b6e68a29582264e
# 2           2017-12-18 00:00:00  48d6d950c0aba132537fc335c0c56e01
# 3           2017-08-21 00:00:00  0b3dc7efaafb0cf78a4796d42fa8d74c
# 4           2018-06-05 00:00:00  abd7e9db219836e58c3fca4965dd14e5
#
#   customer_zip_code_prefix        customer_city customer_state
# 0                    13848           mogi-guacu             SP
# 1                     6519  santana de parnaiba             SP
# 2                     5893            sao paulo             SP
# 3                    22410       rio de janeiro             RJ
# 4                     1042            sao paulo             SP
#
# [5 rows x 32 columns]

# %%
# %%html
# <div class='tableauPlaceholder' id='viz1675727838852' style='position: relative'><noscript><a href='#'><img alt='# OF PURCHASES PER PRODUCT CATEGORY ' src='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;E-&#47;E-commercedataexplorationpurchasesthroughStates&#47;View2&#47;1_rss.png' style='border: none' /></a></noscript><object class='tableauViz'  style='display:none;'><param name='host_url' value='https%3A%2F%2Fpublic.tableau.com%2F' /> <param name='embed_code_version' value='3' /> <param name='site_root' value='' /><param name='name' value='E-commercedataexplorationpurchasesthroughStates&#47;View2' /><param name='tabs' value='no' /><param name='toolbar' value='yes' /><param name='static_image' value='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;E-&#47;E-commercedataexplorationpurchasesthroughStates&#47;View2&#47;1.png' /> <param name='animate_transition' value='yes' /><param name='display_static_image' value='yes' /><param name='display_spinner' value='yes' /><param name='display_overlay' value='yes' /><param name='display_count' value='yes' /><param name='language' value='en-US' /></object></div><script type='text/javascript'>                    var divElement = document.getElementById('viz1675727838852');                    var vizElement = divElement.getElementsByTagName('object')[0];                    if ( divElement.offsetWidth > 800 ) { vizElement.style.width='1000px';vizElement.style.height='827px';} else if ( divElement.offsetWidth > 500 ) { vizElement.style.width='1000px';vizElement.style.height='827px';} else { vizElement.style.width='100%';vizElement.style.height='827px';}                     var scriptElement = document.createElement('script');                    scriptElement.src = 'https://public.tableau.com/javascripts/api/viz_v1.js';                    vizElement.parentNode.insertBefore(scriptElement, vizElement);                </script>
# Out:
# <!doctype html><html lang="en"><head><script charset="UTF-8" src="https://a.sfdcstatic.com/enterprise/tableau/prod/6140/v1/oneTrust/scripttemplates/otSDKStub.js" data-domain-script="2d08f29e-0ede-4e8c-997c-f7ef5be8d4e7" id="one-trust-script"></script><script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-WP98PN');</script><script type="text/plain" class="optanon-category-3">OneTrust.OnConsentChanged(() => String(window.OnetrustActiveGroups).indexOf('3') < 0 && location.reload());</script><script type="text/plain" class="optanon-category-3">;window.NREUM||(NREUM={});NREUM.init={privacy:{cookies_enabled:false},ajax:{deny_list:["bam.nr-data.net"]}};
#   ;NREUM.loader_config={accountID:"885695",trustKey:"194015",agentID:"6776172",licenseKey:"35f2b5d0eb",applicationID:"6776172"}
#   ;NREUM.info={beacon:"bam.nr-data.net",errorBeacon:"bam.nr-data.net",licenseKey:"35f2b5d0eb",applicationID:"6776172",sa:1}
#   window.NREUM||(NREUM={}),__nr_require=function(t,e,n){function r(n){if(!e[n]){var o=e[n]={exports:{}};t[n][0].call(o.exports,function(e){var o=t[n][1][e];return r(o||e)},o,o.exports)}return e[n].exports}if("function"==typeof __nr_require)return __nr_require;for(var o=0;o<n.length;o++)r(n[o]);return r}({1:[function(t,e,n){function r(t){try{s.console&&console.log(t)}catch(e){}}var o,i=t("ee"),a=t(31),s={};try{o=localStorage.getItem("__nr_flags").split(","),console&&"function"==typeof console.log&&(s.console=!0,o.indexOf("dev")!==-1&&(s.dev=!0),o.indexOf("nr_dev")!==-1&&(s.nrDev=!0))}catch(c){}s.nrDev&&i.on("internal-error",function(t){r(t.stack)}),s.dev&&i.on("fn-err",function(t,e,n){r(n.stack)}),s.dev&&(r("NR AGENT IN DEVELOPMENT MODE"),r("flags: "+a(s,function(t,e){return t}).join(", ")))},{}],2:[function(t,e,n){function r(t,e,n,r,s){try{l?l-=1:o(s||new UncaughtException(t,e,n),!0)}catch(f){try{i("ierr",[f,c.now(),!0])}catch(d){}}return"function"==typeof u&&u.apply(this,a(arguments))}function UncaughtException(t,e,n){this.message=t||"Uncaught error with no additional information",this.sourceURL=e,this.line=n}function o(t,e){var n=e?null:c.now();i("err",[t,n])}var i=t("handle"),a=t(32),s=t("ee"),c=t("loader"),f=t("gos"),u=window.onerror,d=!1,p="nr@seenError";if(!c.disabled){var l=0;c.features.err=!0,t(1),window.onerror=r;try{throw new Error}catch(h){"stack"in h&&(t(14),t(13),"addEventListener"in window&&t(7),c.xhrWrappable&&t(15),d=!0)}s.on("fn-start",function(t,e,n){d&&(l+=1)}),s.on("fn-err",function(t,e,n){d&&!n[p]&&(f(n,p,function(){return!0}),this.thrown=!0,o(n))}),s.on("fn-end",function(){d&&!this.thrown&&l>0&&(l-=1)}),s.on("internal-error",function(t){i("ierr",[t,c.now(),!0])})}},{}],3:[function(t,e,n){var r=t("loader");r.disabled||(r.features.ins=!0)},{}],4:[function(t,e,n){function r(){U++,L=g.hash,this[u]=y.now()}function o(){U--,g.hash!==L&&i(0,!0);var t=y.now();this[h]=~~this[h]+t-this[u],this[d]=t}function i(t,e){E.emit("newURL",[""+g,e])}function a(t,e){t.on(e,function(){this[e]=y.now()})}var s="-start",c="-end",f="-body",u="fn"+s,d="fn"+c,p="cb"+s,l="cb"+c,h="jsTime",m="fetch",v="addEventListener",w=window,g=w.location,y=t("loader");if(w[v]&&y.xhrWrappable&&!y.disabled){var x=t(11),b=t(12),E=t(9),R=t(7),O=t(14),T=t(8),S=t(15),P=t(10),M=t("ee"),C=M.get("tracer"),N=t(23);t(17),y.features.spa=!0;var L,U=0;M.on(u,r),b.on(p,r),P.on(p,r),M.on(d,o),b.on(l,o),P.on(l,o),M.buffer([u,d,"xhr-resolved"]),R.buffer([u]),O.buffer(["setTimeout"+c,"clearTimeout"+s,u]),S.buffer([u,"new-xhr","send-xhr"+s]),T.buffer([m+s,m+"-done",m+f+s,m+f+c]),E.buffer(["newURL"]),x.buffer([u]),b.buffer(["propagate",p,l,"executor-err","resolve"+s]),C.buffer([u,"no-"+u]),P.buffer(["new-jsonp","cb-start","jsonp-error","jsonp-end"]),a(T,m+s),a(T,m+"-done"),a(P,"new-jsonp"),a(P,"jsonp-end"),a(P,"cb-start"),E.on("pushState-end",i),E.on("replaceState-end",i),w[v]("hashchange",i,N(!0)),w[v]("load",i,N(!0)),w[v]("popstate",function(){i(0,U>1)},N(!0))}},{}],5:[function(t,e,n){function r(){var t=new PerformanceObserver(function(t,e){var n=t.getEntries();s(v,[n])});try{t.observe({entryTypes:["resource"]})}catch(e){}}function o(t){if(s(v,[window.performance.getEntriesByType(w)]),window.performance["c"+p])try{window.performance[h](m,o,!1)}catch(t){}else try{window.performance[h]("webkit"+m,o,!1)}catch(t){}}function i(t){}if(window.performance&&window.performance.timing&&window.performance.getEntriesByType){var a=t("ee"),s=t("handle"),c=t(14),f=t(13),u=t(6),d=t(23),p="learResourceTimings",l="addEventListener",h="removeEventListener",m="resourcetimingbufferfull",v="bstResource",w="resource",g="-start",y="-end",x="fn"+g,b="fn"+y,E="bstTimer",R="pushState",O=t("loader");if(!O.disabled){O.features.stn=!0,t(9),"addEventListener"in window&&t(7);var T=NREUM.o.EV;a.on(x,function(t,e){var n=t[0];n instanceof T&&(this.bstStart=O.now())}),a.on(b,function(t,e){var n=t[0];n instanceof T&&s("bst",[n,e,this.bstStart,O.now()])}),c.on(x,function(t,e,n){this.bstStart=O.now(),this ...

# %% [markdown]
# **Prepare a list of transactions that customer has made**

# %%
#Filter out all the customers with multiple products purchased into a new dataframe
transactions_df = pdts_customers_df[["customer_id", "customer_unique_id", "product_category_name_english"]]
transactions_df
# Out:
#                              customer_id                customer_unique_id  \
# 0       f8a3e963a310aa58b60a5b1fed5bceb5  b1a1199364a4a7fe27c4486ab63f550d
# 1       12a2c614dfc8926e793516b1638c7471  7139ee1d2ad919a82b6e68a29582264e
# 2       c15eed3881abc9e06763c989679c5094  48d6d950c0aba132537fc335c0c56e01
# 3       6d699e3ab0fd90fffb3d1379d937de77  0b3dc7efaafb0cf78a4796d42fa8d74c
# 4       45d942b1af5529f8990f27848a40e645  abd7e9db219836e58c3fca4965dd14e5
# ...                                  ...                               ...
# 110745  1ce59f480a5fbb7054f9f8e59c577858  8cae259d6dffc5c760fe04bb485d2b6b
# 110746  9cedc9b5217be6c8cb89e73ce5390c1e  f324449067166ef57fea2d94d4cab768
# 110747  c09801227c7f48130b33a8ddb9d91660  882023c0b40dc2130beea608b1196262
# 110748  63155d2512ff588adce41f3fb43f6a6d  f55304849386dd15f067691bd606d75a
# 110749  7f586eb14090136ee43c20ebf1324248  b7cc2e46c75c85df5720044736d2721f
#
#        product_category_name_english
# 0                          perfumery
# 1                          perfumery
# 2                          perfumery
# 3                          perfumery
# 4                          perfumery
# ...                              ...
# 110745             cds_dvds_musicals
# 110746             cds_dvds_musicals
# 110747             cds_dvds_musicals
# 110748             cds_dvds_musicals
# 110749             cds_dvds_musicals
#
# [110750 rows x 3 columns]

# %% [markdown]
# **Prepare list of transactions as TransactionEncoder of mlxtend takes in a list**

# %%
customer_purchase_pdts_list = pdts_customers_df.groupby("customer_unique_id")["product_category_name_english"].unique().to_list()
customer_purchase_pdts_list
# Out:
# [array(['bed_bath_table'], dtype=object),
#  array(['health_beauty'], dtype=object),
#  array(['stationery'], dtype=object),
#  array(['telephony'], dtype=object),
#  array(['telephony'], dtype=object),
#  array(['garden_tools'], dtype=object),
#  array(['telephony'], dtype=object),
#  array(['sports_leisure'], dtype=object),
#  array(['fashion_bags_accessories'], dtype=object),
#  array(['sports_leisure'], dtype=object),
#  array(['bed_bath_table'], dtype=object),
#  array(['luggage_accessories'], dtype=object),
#  array(['bed_bath_table'], dtype=object),
#  array(['computers_accessories'], dtype=object),
#  array(['health_beauty'], dtype=object),
#  array(['fashion_bags_accessories'], dtype=object),
#  array(['bed_bath_table'], dtype=object),
#  array(['telephony'], dtype=object),
#  array(['bed_bath_table'], dtype=object),
#  array(['fashion_underwear_beach'], dtype=object),
#  array(['home_appliances'], dtype=object),
#  array(['computers_accessories'], dtype=object),
#  array(['musical_instruments', 'toys'], dtype=object),
#  array(['home_confort'], dtype=object),
#  array(['bed_bath_table'], dtype=object),
#  array(['housewares'], dtype=object),
#  array(['sports_leisure'], dtype=object),
#  array(['computers_accessories'], dtype=object),
#  array(['luggage_accessories'], dtype=object),
#  array(['small_appliances'], dtype=object),
#  array(['watches_gifts'], dtype=object),
#  array(['health_beauty'], dtype=object),
#  array(['luggage_accessories'], dtype=object),
#  array(['stationery'], dtype=object),
#  array(['bed_bath_table'], dtype=object),
#  array(['computers_accessories', 'electronics'], dtype=object),
#  array(['bed_bath_table', 'furniture_living_room'], dtype=object),
#  array(['computers_accessories'], dtype=object),
#  array(['electronics'], dtype=object),
#  array(['housewares'], dtype=object),
#  array(['sports_leisure'], dtype=object),
#  array(['housewares'], dtype=object),
#  array(['housewares'], dtype=object),
#  array(['electronics'], dtype=object),
#  array(['garden_tools'], dtype=object),
#  array(['housewares'], dtype=object),
#  array(['housewares'], dtype=object),
#  array(['office_furniture'], dtype=object),
#  array(['auto'], dtype=object),
#  array(['auto'], dtype=object),
#  array(['housewares'], dtype=object),
#  array(['furniture_decor'], dtype=object),
#  array(['stationery'], dtype=object),
#  array(['perfumery'], dtype=object),
#  array(['office_furniture'], dtype=object),
#  array(['electronics'], dtype=object),
#  array(['health_beauty'], dtype=object),
#  array(['furniture_decor'], dtype=object),
#  array(['construction_tools_construction'], dtype=object),
#  array(['health_beauty'], dtype=object),
#  array(['fashion_bags_accessories'], dtype=object),
#  array(['health_beauty'], dtype=object),
#  array(['office_furniture'], dtype=object),
#  array(['drinks'], dtype=object),
#  array(['books_general_interest'], dtype=object),
#  array(['housewares'], dtype=object),
#  array(['health_beauty'], dtype=object),
#  array(['electronics'], dtype=object),
#  array(['bed_bath_table'], dtype=object),
#  array(['garden_tools'], dtype=object),
#  array(['consoles_games'], dtype=object),
#  array(['books_general_interest'], dtype=object),
#  array(['housewares'], dtype=object),
#  array(['toys'], dtype=object),
#  array(['furniture_living_room'], dtype=object),
#  array(['cool_stuff'], dtype=object),
#  array(['health_beauty'], dtype=object),
#  array(['home_appliances'], dtype=object),
#  array(['luggage_accessories'], dtype=object),
#  array(['perfumery'], dtype=object),
#  array(['housewares'], dtype=object),
#  array(['furniture_decor'], dtype=object),
#  array(['christmas_supplies'], dtype=object),
#  array(['cool_stuff'], dtype=object),
#  array(['health_beauty'], dtype=object),
#  array(['auto'], dtype=object),
#  array(['furniture_decor'], dtype=object),
#  array(['housewares'], dtype=object),
#  array(['garden_tools'], dtype=object),
#  array(['computers_accessories'], dtype=object),
#  array(['baby'], dtype=object),
#  array(['garden_tools'], dtype=object),
#  array(['furniture_decor'], dtype=object),
#  array(['pet_shop'], dtype=object),
#  array(['sports_leisure'], dtype=object),
#  array(['bed_bath_table'], dtype=object),
#  array(['bed_bath_table'], dtype=object),
#  array(['books_general_interest'], dtype=object),
#  array(['toys'], dtype=object),
#  array(['health_beauty'], dtype=object),
#  array(['bed_bath_table'], dtype=object),
#  array(['sports_leisure'], dtype=object),
#  array(['office_furniture'], dtype=object),
#  array(['telephony'], dtype=object),
#  array(['cool_stuff', 'luggage_accessories'], dtype=object),
#  array(['health_beauty'], dtype=object),
#  array(['baby'], dtype=object),
#  array(['bed_bath_table'], dtype=object),
#  array(['computers_accessories'], dtype=object),
#  array(['bed_bath_table'], dtype=object),
#  array(['toys'], dtype=object),
#  array(['housewares'], dtype=object),
#  array(['toys'], dtype=object),
#  array(['pet_shop'], dtype=object),
#  array(['health_beauty'], dtype=object),
#  array(['home_construction'], dtype=object),
#  array(['telephony'], dtype=object),
#  array(['housewares'], dtype=object),
#  array(['furniture_decor'], dtype=object),
#  array(['telephony'], dtype=object),
#  array(['furniture_decor', 'garden_tools'], dtype=object),
#  array(['sports_leisure'], dtype=object),
#  array(['health_beauty'], dtype=object),
#  array(['watches_gifts'], dtype=object),
#  array(['luggage_accessories'], dtype=object),
#  array(['office_furniture'], dtype=object),
#  array(['bed_bath_table'], dtype=object),
#  array(['health_beauty'], dtype=object),
#  array(['furniture_living_room'], dtype=object),
#  array(['home_appliances_2'], dtype=object),
#  array(['furniture_decor'], dtype=object),
#  array(['computers_accessories'], dtype=object),
#  array(['small_appliances'], dtype=object),
#  array(['books_general_interest'], dtype=object),
#  array(['housewares'], dtype=object),
#  array(['bed_bath_table'], dtype=object),
#  array(['health_beauty'], dtype=object),
#  array(['electronics'], dtype=object),
#  array(['furniture_decor'], dtype=object),
#  array(['furniture_decor'], dtype=object),
#  array(['luggage_accessories', 'stationery'], dtype=object),
#  array(['electronics'], dtype=object),
#  array(['bed_bath_table'], dtype=object),
#  array(['housewares'], dtype=object),
#  array(['sports_leisure'], dtype=object),
#  array(['watches_gifts'], dtype=object),
#  array(['bed_bath_table'], dtype=object),
#  array(['furniture_decor'], dtype=object),
#  array(['office_furniture'], dtype=object),
#  array(['bed_bath_table'], dtype=object),
#  array(['baby'], dtype=object),
#  array(['cool_stuff'], dtype=object),
#  array(['health_beauty'], dtype=object),
#  array(['telephony'], dtype=object),
#  array(['garden_tools'], dtype=object),
#  array(['housewares'], dtype=object),
#  array(['auto'], dtype=object),
#  array(['pet_shop'], dtype=object),
#  array(['stationery'], dtype=object),
#  array(['sports_leisure'], dtype=object),
#  array(['baby'], dtype=object),
#  array(['bed_bath_table'], dtype=object),
#  array(['garden_tools'], dtype=object),
#  array(['toys'], dtype=object),
#  array(['stationery'], dtype=object),
#  array(['housewares'], dtype=object),
#  array(['computers_accessories'], dtype=object),
#  array(['cool_stuff'], dtype=object),
#  array(['telephony'], dtype=object),
#  array(['computers_accessories'], dtype=object),
#  array(['garden_tools'], dtype=object),
#  array(['sports_leisure'], dtype=object),
#  array(['housewares'], dtype=object),
#  array(['baby'], dtype=object),
#  array(['watches_gifts'], dtype=object),
#  array(['bed_bath_table'], dtype=object),
#  array(['office_furniture'], dtype=object),
#  array(['toys'], dtype=object),
#  array(['furniture_decor'], dtype=object),
#  array(['bed_bath_table'], dtype=object),
#  array(['toys'], dtype=object),
#  array(['luggage_accessories'], dtype=object),
#  array(['office_furniture'], dtype=object),
#  array(['watches_gifts'], dtype=object),
#  array(['health_beauty'], dtype=object),
#  array(['telephony'], dtype=object),
#  array(['cool_stuff'], dtype=object),
#  array(['garden_tools'], dtype=object),
#  array(['sports_leisure'], dtype=object),
#  array(['watches_gifts'], dtype=object),
#  array(['sports_leisure'], dtype=object),
#  array(['furniture_decor'], dtype=object),
#  array(['electronics'], dtype=object),
#  array(['bed_bath_table'], dtype=object),
#  array(['health_beauty'], dtype=object),
#  array(['home_construction'], dtype=object),
#  array(['housewares'], dtype=object),
#  array(['furniture_decor'], dtype=object),
#  array(['sports_leisure'], dtype=object),
#  array(['health_beauty'], dtype=object),
#  array(['health_beauty'], dtype=object),
#  array(['health_beauty'], dtype=object),
#  array(['garden_tools'], dtype=object),
#  array(['housewares'], dtype=object),
#  array(['baby'], dtype=object),
#  array(['stationery'], dtype=object),
#  array(['health_beauty'], dtype=object),
#  array(['watches_gifts'], dtype=object),
#  array(['perfumery'], dtype=object),
#  array(['fixed_telephony'], dtype=object),
#  array(['toys'], dtype=object),
#  array(['garden_tools'], dtype=object),
#  array(['toys'], dtype=object),
#  array(['electronics'], dtype=object),
#  array(['perfumery'], dtype=object),
#  array(['cool_stuff'], dtype=object),
#  array(['bed_bath_table'], dtype=object),
#  array(['computers_accessories'], dtype=object),
#  array(['fashion_underwear_beach'], dtype=object),
#  array(['baby'], dtype=object),
#  array(['cool_stuff'], dtype=object),
#  array(['housewares'], dtype=object),
#  array(['furniture_decor'], dtype=object),
#  array(['computers_accessories'], dtype=object),
#  array(['sports_leisure'], dtype=object),
#  array(['furniture_decor'], dtype=object),
#  array(['furniture_decor', 'flowers'], dtype=object),
#  array(['stationery'], dtype=object),
#  array(['toys'], dtype=object),
#  array(['health_beauty'], dtype=object),
#  array(['pet_shop'], dtype=object),
#  array(['books_imported'], dtype=object),
#  array(['electronics'], dtype=object),
#  array(['furniture_decor'], dtype=object),
#  array(['baby'], dtype=object),
#  array(['health_beauty'], dtype=object),
#  array(['computers_accessories'], dtype=object),
#  array(['health_beauty'], dtype=object),
#  array(['perfumery'], dtype=object),
#  array(['watches_gifts'], dtype=object),
#  array(['cool_stuff'], dtype=object),
#  array(['computers_accessories'], dtype=object),
#  array(['housewares'], dtype=object),
#  array(['sports_leisure', 'electronics'], dtype=object),
#  array(['pet_shop'], dtype=object),
#  array(['sports_leisure'], dtype=object),
#  array(['toys'], dtype=object),
#  array(['sports_leisure'], dtype=object),
#  array(['cool_stuff'], dtype=object),
#  array(['baby'], dtype=object),
#  array(['bed_bath_table'], dtype=object),
#  array(['perfumery'], dtype=object),
#  array(['auto'], dtype=object),
#  array(['luggage_accessories'], dtype=object),
#  array(['pet_shop'], dtype=object),
#  array(['luggage_accessories'], dtype=object),
#  array(['watches_gifts'], dtype=object),
#  array(['baby', 'furniture_decor'], dtype=object),
#  array(['health_beauty'], dtype=object),
#  array(['drinks'], dtype=object),
#  array(['pet_shop'], dtype=object),
#  array(['construction_tools_safety'], dtype=object),
#  array(['health_beauty'], dtype=object),
#  array(['perfumery'], dtype=object),
#  array(['stationery'], dtype=object),
#  array(['home_confort'], dtype=object),
#  array(['health_beauty'], dtype=object),
#  array(['sports_leisure'], dtype=object),
#  array(['toys'], dtype=object),
#  array(['bed_bath_table'], dtype=object),
#  array(['bed_bath_table'], dtype=object),
#  array(['telephony'], dtype=object),
#  array(['office_furniture'], dtype=object),
#  array(['auto'], dtype=object),
#  array(['furniture_decor'], dtype=object),
#  array(['perfumery'], dtype=object),
#  array(['bed_bath_table'], dtype=object),
#  array(['garden_tools'], dtype=object),
#  array(['toys'], dtype=object),
#  array(['electronics'], dtype=object),
#  array(['furniture_decor'], dtype=object),
#  array(['stationery'], dtype=object),
#  array(['furniture_decor'], dtype=object),
#  array(['garden_tools'], dtype=object),
#  array(['garden_tools'], dtype=object),
#  array(['furniture_living_room'], dtype=object),
#  array(['computers_accessories'], dtype=object),
#  array(['toys'], dtype=object),
#  array(['auto'], dtype=object),
#  array(['pet_shop'], dtype=object),
#  array(['books_general_interest'], dtype=object),
#  array(['garden_tools'], dtype=object),
#  array(['electronics'], dtype=object),
#  array(['construction_tools_construction'], dtype=object),
#  array(['fashion_bags_accessories'], dtype=object),
#  array(['health_beauty'], dtype=object),
#  array(['christmas_supplies'], dtype=object),
#  array(['health_beauty'], dtype=object),
#  array(['electronics'], dtype=object),
#  array(['computers_accessories'], dtype=object),
#  array(['furniture_decor'], dtype=object),
#  array(['toys'], dtype=object),
#  array(['diapers_and_hygiene'], dtype=object),
#  array(['office_furniture'], dtype=object),
#  array(['computers_accessories'], dtype=object),
#  array(['home_appliances', 'bed_bath_table'], dtype=object),
#  array(['bed_bath_table'], dtype=object),
#  array(['fashion_shoes'], dtype=object),
#  array(['bed_bath_table'], dtype=object),
#  array(['furniture_decor'], dtype=object),
#  array(['baby'], dtype=object),
#  array(['bed_bath_table'], dtype=object),
#  array(['bed_bath_table'], dtype=object),
#  array(['electronics'], dtype=object),
#  array(['fixed_telephony'], dtype=object),
#  array(['perfumery'], dtype=object),
#  array(['sports_leisure'], dtype=object),
#  array(['fashion_bags_accessories'], dtype=object),
#  array(['baby'], dtype=object),
#  array(['bed_bath_table'], dtype=object),
#  array(['computers_accessories'], dtype=object),
#  array(['health_beauty'], dtype=object),
#  array(['bed_bath_table'], dtype=object),
#  array(['cool_stuff'], dtype=object),
#  array(['telephony'], dtype=object),
#  array(['computers_accessories'], dtype=object),
#  array(['kitchen_dining_laundry_garden_furniture'], dtype=object),
#  array(['telephony'], dtype=object),
#  array(['furniture_decor'], dtype=object),
#  array(['books_general_interest'], dtype=object),
#  array(['computers_accessories'], dtype=object),
#  array(['furniture_decor'], dtype=object),
#  array(['toys'], dtype=object),
#  array(['baby'], dtype=object),
#  array(['baby'], dtype=object),
#  array(['auto'], dtype=object),
#  array(['computers_accessories'], dtype=object),
#  array(['health_beauty'], dtype=object),
#  array(['art'], dtype=object),
#  array(['stationery'], dtype=object),
#  array(['cool_stuff'], dtype=object),
#  array(['electronics'], dtype=object),
#  array(['bed_bath_table'], dtype=object),
#  array(['garden_tools'], dtype=object),
#  array(['baby'], dtype=object),
#  array(['perfumery'], dtype=object),
#  array(['furniture_decor'], dtype=object),
#  array(['fashion_bags_accessories'], dtype=object),
#  array(['housewares'], dtype=object),
#  array(['computers_accessories'], dtype=object),
#  array(['auto'], dtype=object),
#  array(['health_beauty'], dtype=object),
#  array(['perfumery'], dtype=object),
#  array(['auto'], dtype=object),
#  array(['furniture_decor'], dtype=object),
#  array(['bed_bath_table'], dtype=object),
#  array(['garden_tools'], dtype=object),
#  array(['stationery'], dtype=object),
#  array(['housewares', 'bed_bath_table'], dtype=object),
#  array(['health_beauty'], dtype=object),
#  array(['bed_bath_table'], dtype=object),
#  array(['bed_bath_table'], dtype=object),
#  array(['auto'], dtype=object),
#  array(['baby'], dtype=object),
#  array(['computers_accessories'], dtype=object),
#  array(['food_drink'], dtype=object),
#  array(['bed_bath_table'], dtype=object),
#  array(['computers_accessories'], dtype=object),
#  array(['housewares'], dtype=object),
#  array(['bed_bath_table'], dtype=object),
#  array(['health_beauty'], dtype=object),
#  array(['cool_stuff'], dtype=object),
#  array(['garden_tools', 'auto'], dtype=object),
#  array(['health_beauty'], dtype=object),
#  array(['health_beauty'], dtype=object),
#  array(['auto'], dtype=object),
#  array(['stationery'], dtype=object),
#  array(['office_furniture'], dtype=object),
#  array(['luggage_accessories'], dtype=object),
#  array(['bed_bath_table'], dtype=object),
#  array(['food'], dtype=object),
#  array(['bed_bath_table'], dtype=object),
#  array(['furniture_decor'], dtype=object),
#  array(['watches_gifts'], dtype=object),
#  array(['perfumery'], dtype=object),
#  array(['office_furniture'], dtype=object),
#  array(['housewares'], dtype=object),
#  array(['cool_stuff'], dtype=object),
#  array(['books_technical'], dtype=object),
#  array(['cool_stuff'], dtype=object),
#  array(['bed_bath_table'], dtype=object),
#  array(['computers_accessories'], dtype=object),
#  array(['drinks'], dtype=object),
#  array(['sports_leisure'], dtype=object),
#  array(['luggage_accessories'], dtype=object),
#  array(['bed_bath_table'], dtype=object),
#  array(['furniture_living_room'], dtype=object),
#  array(['computers_accessories'], dtype=object),
#  array(['sports_leisure'], dtype=object),
#  array(['bed_bath_table'], dtype=object),
#  array(['auto'], dtype=object),
#  array(['watches_gifts'], dtype=object),
#  array(['stationery'], dtype=object),
#  array(['watches_gifts'], dtype=object),
#  array(['musical_instruments', 'toys'], dtype=object),
#  array(['electronics'], dtype=object),
#  array(['bed_bath_table'], dtype=object),
#  array(['sports_leisure'], dtype=object),
#  array(['musical_instruments'], dtype=object),
#  array(['auto'], dtype=object),
#  array(['baby'], dtype=object),
#  array(['industry_commerce_and_business'], dtype=object),
#  array(['garden_tools'], dtype=object),
#  array(['sports_leisure'], dtype=object),
#  array(['perfumery'], dtype=object),
#  array(['auto'], dtype=object),
#  array(['watches_gifts'], dtype=object),
#  array(['audio'], dtype=object),
#  array(['watches_gifts'], dtype=object),
#  array(['sports_leisure', 'food'], dtype=object),
#  array(['cool_stuff'], dtype=object),
#  array(['health_beauty'], dtype=object),
#  array(['toys'], dtype=object),
#  array(['office_furniture'], dtype=object),
#  array(['cool_stuff'], dtype=object),
#  array(['electronics'], dtype=object),
#  array(['sports_leisure'], dtype=object),
#  array(['furniture_decor'], dtype=object),
#  array(['health_beauty', 'office_furniture'], dtype=object),
#  array(['perfumery'], dtype=object),
#  array(['cool_stuff'], dtype=object),
#  array(['sports_leisure'], dtype=object),
#  array(['bed_bath_table'], dtype=object),
#  array(['health_beauty'], dtype=object),
#  array(['auto'], dtype=object),
#  array(['toys'], dtype=object),
#  array(['stationery'], dtype=object),
#  array(['auto'], dtype=object),
#  array(['auto'], dtype=object),
#  array(['food_drink'], dtype=object),
#  array(['furniture_decor', 'construction_tools_lights'], dtype=object),
#  array(['sports_leisure'], dtype=object),
#  array(['health_beauty'], dtype=object),
#  array(['watches_gifts'], dtype=object),
#  array(['sports_leisure'], dtype=object),
#  array(['housewares'], dtype=object),
#  array(['books_technical'], dtype=object),
#  array(['furniture_decor'], dtype=object),
#  array(['toys'], dtype=object),
#  array(['cool_stuff'], dtype=object),
#  array(['kitchen_dining_laundry_garden_furniture'], dtype=object),
#  array(['health_beauty'], dtype=object),
#  array(['stationery'], dtype=object),
#  array(['garden_tools'], dtype=object),
#  array(['health_beauty'], dtype=object),
#  array(['garden_tools'], dtype=object),
#  array(['sports_leisure'], dtype=object),
#  array(['perfumery'], dtype=object),
#  array(['musical_instruments'], dtype=object),
#  array(['signaling_and_security'], dtype=object),
#  array(['electronics'], dtype=object),
#  array(['computers_accessories'], dtype=object),
#  array(['pet_shop'], dtype=object),
#  array(['baby'], dtype=object),
#  array(['garden_tools'], dtype=object),
#  array(['electronics'], dtype=object),
#  array(['auto'], dtype=object),
#  array(['musical_instruments', 'toys'], dtype=object),
#  array(['housewares'], dtype=object),
#  array(['sports_leisure'], dtype=object),
#  array(['stationery'], dtype=object),
#  array(['housewares'], dtype=object),
#  array(['cool_stuff'], dtype=object),
#  array(['housewares'], dtype=object),
#  array(['luggage_accessories'], dtype=object),
#  array(['office_furniture'], dtype=object),
#  array(['telephony'], dtype=object),
#  array(['perfumery'], dtype=object),
#  array(['health_beauty'], dtype=object),
#  array(['auto'], dtype=object),
#  array(['housewares'], dtype=object),
#  array(['electronics'], dtype=object),
#  array(['stationery'], dtype=object),
#  array(['bed_bath_table'], dtype=object),
#  array(['health_beauty'], dtype=object),
#  array(['fashion_bags_accessories'], dtype=object),
#  array(['housewares'], dtype=object),
#  array(['fashion_bags_accessories'], dtype=object),
#  array(['fashion_bags_accessories'], dtype=object),
#  array(['toys'], dtype=object),
#  array(['sports_leisure'], dtype=object),
#  array(['small_appliances'], dtype=object),
#  array(['baby'], dtype=object),
#  array(['home_construction'], dtype=object),
#  array(['fashion_bags_accessories'], dtype=object),
#  array(['sports_leisure'], dtype=object),
#  array(['watches_gifts'], dtype=object),
#  array(['food'], dtype=object),
#  array(['small_appliances'], dtype=object),
#  array(['housewares'], dtype=object),
#  array(['toys'], dtype=object),
#  array(['housewares', 'bed_bath_table'], dtype=object),
#  array(['garden_tools'], dtype=object),
#  array(['garden_tools'], dtype=object),
#  array(['bed_bath_table'], dtype=object),
#  array(['baby'], dtype=object),
#  array(['cool_stuff'], dtype=object),
#  array(['furniture_decor'], dtype=object),
#  array(['cool_stuff'], dtype=object),
#  array(['computers_accessories'], dtype=object),
#  array(['pet_shop'], dtype=object),
#  array(['perfumery'], dtype=object),
#  array(['computers_accessories'], dtype=object),
#  array(['electronics'], dtype=object),
#  array(['cool_stuff'], dtype=object),
#  array(['telephony'], dtype=object),
#  array(['watches_gifts'], dtype=object),
#  array(['home_appliances_2'], dtype=object),
#  array(['sports_leisure'], dtype=object),
#  array(['sports_leisure'], dtype=object),
#  array(['furniture_living_room'], dtype=object),
#  array(['electronics'], dtype=object),
#  array(['furniture_decor'], dtype=object),
#  array(['housewares'], dtype=object),
#  array(['computers_accessories'], dtype=object),
#  array(['computers_accessories'], dtype=object),
#  array(['bed_bath_table'], dtype=object),
#  array(['furniture_decor'], dtype=object),
#  array(['computers_accessories'], dtype=object),
#  array(['bed_bath_table'], dtype=object),
#  array(['electronics'], dtype=object),
#  array(['bed_bath_table'], dtype=object),
#  array(['toys'], dtype=object),
#  array(['furniture_decor', 'office_furniture'], dtype=object),
#  array(['cool_stuff'], dtype=object),
#  array(['small_appliances'], dtype=object),
#  array(['fashion_bags_accessories'], dtype=object),
#  array(['computers_accessories'], dtype=object),
#  array(['pet_shop'], dtype=object),
#  array(['computers_accessories'], dtype=object),
#  array(['computers_accessories'], dtype=object),
#  array(['market_place'], dtype=object),
#  array(['stationery'], dtype=object),
#  array(['sports_leisure'], dtype=object),
#  array(['computers_accessories'], dtype=object),
#  array(['sports_leisure'], dtype=object),
#  array(['bed_bath_table'], dtype=object),
#  array(['electronics'], dtype=object),
#  array(['sports_leisure'], dtype=object),
#  array(['health_beauty'], dtype=object),
#  array(['telephony'], dtype=object),
#  array(['housewares'], dtype=object),
#  array(['office_furniture'], dtype=object),
#  array(['bed_bath_table'], dtype=object),
#  array(['health_beauty'], dtype=object),
#  array(['sports_leisure'], dtype=object),
#  array(['bed_bath_table'], dtype=object),
#  array(['watches_gifts'], dtype=object),
#  array(['fashion_shoes'], dtype=object),
#  array(['stationery'], dtype=object),
#  array(['books_technical'], dtype=object),
#  array(['housewares'], dtype=object),
#  array(['housewares'], dtype=object),
#  array(['garden_tools'], dtype=object),
#  array(['electronics'], dtype=object),
#  array(['auto'], dtype=object),
#  array(['pet_shop'], dtype=object),
#  array(['food'], dtype=object),
#  array(['fashion_male_clothing'], dtype=object),
#  array(['office_furniture'], dtype=object),
#  array(['bed_bath_table'], dtype=object),
#  array(['housewares'], dtype=object),
#  array(['auto'], dtype=object),
#  array(['housewares'], dtype=object),
#  array(['housewares'], dtype=object),
#  array(['sports_leisure'], dtype=object),
#  array(['stationery'], dtype=object),
#  array(['health_beauty'], dtype=object),
#  array(['auto'], dtype=object),
#  array(['sports_leisure'], dtype=object),
#  array(['audio'], dtype=object),
#  array(['health_beauty'], dtype=object),
#  array(['housewares'], dtype=object),
#  array(['perfumery'], dtype=object),
#  array(['telephony'], dtype=object),
#  array(['computers_accessories'], dtype=object),
#  array(['fashion_bags_accessories'], dtype=object),
#  array(['computers_accessories'], dtype=object),
#  array(['sports_leisure'], dtype=object),
#  array(['stationery'], dtype=object),
#  array(['bed_bath_table'], dtype=object),
#  array(['sports_leisure'], dtype=object),
#  array(['fashion_bags_accessories'], dtype=object),
#  array(['bed_bath_table'], dtype=object),
#  array(['health_beauty'], dtype=object),
#  array(['bed_bath_table'], dtype=object),
#  array(['health_beauty'], dtype=object),
#  array(['housewares'], dtype=object),
#  array(['perfumery'], dtype=object),
#  array(['bed_bath_table'], dtype=object),
#  array(['cine_photo'], dtype=object),
#  array(['electronics'], dtype=object),
#  array(['auto'], dtype=object),
#  array(['bed_bath_table'], dtype=object),
#  array(['pet_shop'], dtype=object),
#  array(['baby'], dtype=object),
#  array(['health_beauty'], dtype=object),
#  array(['garden_tools'], dtype=object),
#  array(['sports_leisure'], dtype=object),
#  array(['auto'], dtype=object),
#  array(['bed_bath_table'], dtype=object),
#  array(['baby'], dtype=object),
#  array(['watches_gifts'], dtype=object),
#  array(['sports_leisure'], dtype=object),
#  array(['computers_accessories'], dtype=object),
#  array(['health_beauty'], dtype=object),
#  array(['costruction_tools_garden'], dtype=object),
#  array(['watches_gifts'], dtype=object),
#  array(['perfumery'], dtype=object),
#  array(['bed_bath_table'], dtype=object),
#  array(['agro_industry_and_commerce'], dtype=object),
#  array(['toys'], dtype=object),
#  array(['watches_gifts'], dtype=object),
#  array(['luggage_accessories'], dtype=object),
#  array(['telephony'], dtype=object),
#  array(['housewares'], dtype=object),
#  array(['bed_bath_table'], dtype=object),
#  array(['health_beauty'], dtype=object),
#  array(['housewares'], dtype=object),
#  array(['musical_instruments'], dtype=object),
#  array(['home_appliances'], dtype=object),
#  array(['auto'], dtype=object),
#  array(['toys'], dtype=object),
#  array(['construction_tools_construction'], dtype=object),
#  array(['toys'], dtype=object),
#  array(['sports_leisure'], dtype=object),
#  array(['consoles_games'], dtype=object),
#  array(['electronics'], dtype=object),
#  array(['home_construction'], dtype=object),
#  array(['telephony'], dtype=object),
#  array(['books_technical'], dtype=object),
#  array(['health_beauty'], dtype=object),
#  array(['toys'], dtype=object),
#  array(['watches_gifts'], dtype=object),
#  array(['home_confort'], dtype=object),
#  array(['bed_bath_table'], dtype=object),
#  array(['sports_leisure'], dtype=object),
#  array(['watches_gifts'], dtype=object),
#  array(['stationery'], dtype=object),
#  array(['sports_leisure'], dtype=object),
#  array(['auto'], dtype=object),
#  array(['telephony'], dtype=object),
#  array(['furniture_living_room'], dtype=object),
#  array(['computers_accessories'], dtype=object),
#  array(['health_beauty'], dtype=object),
#  array(['office_furniture'], dtype=object),
#  array(['health_beauty'], dtype=object),
#  array(['watches_gifts'], dtype=object),
#  array(['home_appliances'], dtype=object),
#  array(['electronics'], dtype=object),
#  array(['telephony'], dtype=object),
#  array(['computers_accessories'], dtype=object),
#  array(['computers_accessories'], dtype=object),
#  array(['auto'], dtype=object),
#  array(['bed_bath_table'], dtype=object),
#  array(['furniture_decor'], dtype=object),
#  array(['computers_accessories'], dtype=object),
#  array(['telephony'], dtype=object),
#  array(['fashion_bags_accessories'], dtype=object),
#  array(['telephony'], dtype=object),
#  array(['baby'], dtype=object),
#  array(['computers_accessories'], dtype=object),
#  array(['health_beauty'], dtype=object),
#  array(['art'], dtype=object),
#  array(['toys'], dtype=object),
#  array(['baby'], dtype=object),
#  array(['industry_commerce_and_business'], dtype=object),
#  array(['watches_gifts'], dtype=object),
#  array(['consoles_games'], dtype=object),
#  array(['stationery'], dtype=object),
#  array(['toys'], dtype=object),
#  array(['bed_bath_table'], dtype=object),
#  array(['computers_accessories'], dtype=object),
#  array(['perfumery'], dtype=object),
#  array(['watches_gifts'], dtype=object),
#  array(['garden_tools'], dtype=object),
#  array(['computers_accessories'], dtype=object),
#  array(['garden_tools'], dtype=object),
#  array(['toys'], dtype=object),
#  array(['perfumery'], dtype=object),
#  array(['health_beauty'], dtype=object),
#  array(['fixed_telephony'], dtype=object),
#  array(['cool_stuff'], dtype=object),
#  array(['electronics'], dtype=object),
#  array(['office_furniture'], dtype=object),
#  array(['auto'], dtype=object),
#  array(['computers_accessories'], dtype=object),
#  array(['computers_accessories'], dtype=object),
#  array(['health_beauty'], dtype=object),
#  array(['telephony'], dtype=object),
#  array(['watches_gifts'], dtype=object),
#  array(['cool_stuff'], dtype=object),
#  array(['bed_bath_table'], dtype=object),
#  array(['consoles_games'], dtype=object),
#  array(['computers_accessories'], dtype=object),
#  array(['sports_leisure'], dtype=object),
#  array(['telephony'], dtype=object),
#  array(['garden_tools'], dtype=object),
#  array(['cool_stuff', 'bed_bath_table'], dtype=object),
#  array(['watches_gifts'], dtype=object),
#  array(['computers_accessories', 'kitchen_dining_laundry_garden_furniture'],
#        dtype=object),
#  array(['baby'], dtype=object),
#  array(['health_beauty'], dtype=object),
#  array(['market_place'], dtype=object),
#  array(['computers_accessories'], dtype=object),
#  array(['housewares'], dtype=object),
#  array(['computers_accessories'], dtype=object),
#  array(['health_beauty'], dtype=object),
#  array(['watches_gifts'], dtype=object),
#  array(['watches_gifts'], dtype=object),
#  array(['furniture_decor'], dtype=object),
#  array(['computers_accessories'], dtype=object),
#  array(['health_beauty'], dtype=object),
#  array(['telephony'], dtype=object),
#  array(['sports_leisure'], dtype=object),
#  array(['watches_gifts'], dtype=object),
#  array(['computers_accessories'], dtype=object),
#  array(['auto'], dtype=object),
#  array(['bed_bath_table'], dtype=object),
#  array(['electronics'], dtype=object),
#  array(['computers_accessories'], dtype=object),
#  array(['consoles_games'], dtype=object),
#  array(['consoles_games'], dtype=object),
#  array(['stationery'], dtype=object),
#  array(['furniture_decor'], dtype=object),
#  array(['furniture_decor'], dtype=object),
#  array(['auto'], dtype=object),
#  array(['baby'], dtype=object),
#  array(['cool_stuff'], dtype=object),
#  array(['perfumery'], dtype=object),
#  array(['agro_industry_and_commerce'], dtype=object),
#  array(['health_beauty'], dtype=object),
#  array(['health_beauty'], dtype=object),
#  array(['watches_gifts'], dtype=object),
#  array(['construction_tools_safety'], dtype=object),
#  array(['sports_leisure'], dtype=object),
#  array(['computers_accessories'], dtype=object),
#  array(['furniture_decor'], dtype=object),
#  array(['toys'], dtype=object),
#  array(['bed_bath_table'], dtype=object),
#  array(['bed_bath_table'], dtype=object),
#  array(['health_beauty'], dtype=object),
#  array(['bed_bath_table'], dtype=object),
#  array(['telephony'], dtype=object),
#  array(['toys'], dtype=object),
#  array(['health_beauty'], dtype=object),
#  array(['perfumery'], dtype=object),
#  array(['bed_bath_table'], dtype=object),
#  array(['office_furniture'], dtype=object),
#  array(['sports_leisure'], dtype=object),
#  array(['auto'], dtype=object),
#  array(['office_furniture'], dtype=object),
#  array(['health_beauty'], dtype=object),
#  array(['furniture_decor'], dtype=object),
#  array(['electronics'], dtype=object),
#  array(['sports_leisure'], dtype=object),
#  array(['sports_leisure'], dtype=object),
#  array(['housewares'], dtype=object),
#  array(['watches_gifts'], dtype=object),
#  array(['telephony'], dtype=object),
#  array(['perfumery'], dtype=object),
#  array(['construction_tools_construction'], dtype=object),
#  array(['art'], dtype=object),
#  array(['luggage_accessories'], dtype=object),
#  array(['sports_leisure'], dtype=object),
#  array(['pet_shop'], dtype=object),
#  array(['sports_leisure'], dtype=object),
#  array(['health_beauty'], dtype=object),
#  array(['sports_leisure'], dtype=object),
#  array(['consoles_games'], dtype=object),
#  array(['electronics'], dtype=object),
#  array(['fashion_bags_accessories'], dtype=object),
#  array(['stationery'], dtype=object),
#  array(['construction_tools_construction'], dtype=object),
#  array(['sports_leisure'], dtype=object),
#  array(['garden_tools'], dtype=object),
#  array(['watches_gifts'], dtype=object),
#  array(['perfumery'], dtype=object),
#  array(['toys'], dtype=object),
#  array(['home_appliances_2'], dtype=object),
#  array(['auto'], dtype=object),
#  array(['computers_accessories'], dtype=object),
#  array(['cool_stuff'], dtype=object),
#  array(['auto'], dtype=object),
#  array(['bed_bath_table'], dtype=object),
#  array(['cool_stuff'], dtype=object),
#  array(['health_beauty'], dtype=object),
#  array(['books_general_interest'], dtype=object),
#  array(['furniture_decor'], dtype=object),
#  array(['garden_tools'], dtype=object),
#  array(['computers_accessories'], dtype=object),
#  array(['telephony'], dtype=object),
#  array(['sports_leisure'], dtype=object),
#  array(['health_beauty'], dtype=object),
#  array(['perfumery'], dtype=object),
#  array(['health_beauty'], dtype=object),
#  array(['health_beauty'], dtype=object),
#  array(['bed_bath_table'], dtype=object),
#  array(['food_drink'], dtype=object),
#  array(['telephony'], dtype=object),
#  array(['sports_leisure'], dtype=object),
#  array(['sports_leisure'], dtype=object),
#  array(['watches_gifts'], dtype=object),
#  array(['fashion_bags_accessories'], dtype=object),
#  array(['telephony'], dtype=object),
#  array(['watches_gifts'], dtype=object),
#  array(['auto'], dtype=object),
#  array(['sports_leisure'], dtype=object),
#  array(['watches_gifts'], dtype=object),
#  array(['garden_tools'], dtype=object),
#  array(['computers_accessories', 'consoles_games'], dtype=object),
#  array(['watches_gifts'], dtype=object),
#  array(['sports_leisure'], dtype=object),
#  array(['toys'], dtype=object),
#  array(['watches_gifts'], dtype=object),
#  array(['art'], dtype=object),
#  array(['telephony'], dtype=object),
#  array(['computers_accessories'], dtype=object),
#  array(['home_construction'], dtype=object),
#  array(['furniture_decor'], dtype=object),
#  array(['electronics'], dtype=object),
#  array(['health_beauty'], dtype=object),
#  array(['auto'], dtype=object),
#  array(['perfumery'], dtype=object),
#  array(['electronics'], dtype=object),
#  array(['housewares'], dtype=object),
#  array(['home_appliances'], dtype=object),
#  array(['home_appliances'], dtype=object),
#  array(['pet_shop'], dtype=object),
#  array(['electronics'], dtype=object),
#  array(['health_beauty'], dtype=object),
#  array(['watches_gifts'], dtype=object),
#  array(['bed_bath_table'], dtype=object),
#  array(['sports_leisure'], dtype=object),
#  array(['health_beauty'], dtype=object),
#  array(['computers_accessories'], dtype=object),
#  array(['telephony'], dtype=object),
#  array(['housewares'], dtype=object),
#  array(['cool_stuff'], dtype=object),
#  array(['cool_stuff'], dtype=object),
#  array(['furniture_decor'], dtype=object),
#  array(['sports_leisure'], dtype=object),
#  array(['stationery'], dtype=object),
#  array(['health_beauty'], dtype=object),
#  array(['home_construction'], dtype=object),
#  array(['toys'], dtype=object),
#  array(['furniture_decor'], dtype=object),
#  array(['health_beauty'], dtype=object),
#  array(['furniture_decor'], dtype=object),
#  array(['auto'], dtype=object),
#  array(['toys'], dtype=object),
#  array(['bed_bath_table'], dtype=object),
#  array(['furniture_decor'], dtype=object),
#  array(['auto'], dtype=object),
#  array(['electronics'], dtype=object),
#  array(['bed_bath_table'], dtype=object),
#  array(['flowers'], dtype=object),
#  array(['office_furniture'], dtype=object),
#  array(['housewares'], dtype=object),
#  array(['health_beauty'], dtype=object),
#  array(['sports_leisure', 'watches_gifts'], dtype=object),
#  array(['toys'], dtype=object),
#  array(['cool_stuff'], dtype=object),
#  array(['fashion_bags_accessories'], dtype=object),
#  array(['audio'], dtype=object),
#  array(['watches_gifts'], dtype=object),
#  array(['housewares'], dtype=object),
#  array(['health_beauty'], dtype=object),
#  array(['fashion_bags_accessories'], dtype=object),
#  array(['toys'], dtype=object),
#  array(['garden_tools'], dtype=object),
#  array(['home_construction'], dtype=object),
#  array(['garden_tools'], dtype=object),
#  array(['sports_leisure'], dtype=object),
#  array(['perfumery'], dtype=object),
#  array(['auto'], dtype=object),
#  array(['perfumery'], dtype=object),
#  array(['housewares'], dtype=object),
#  array(['furniture_decor'], dtype=object),
#  array(['bed_bath_table', 'furniture_living_room'], dtype=object),
#  array(['perfumery'], dtype=object),
#  array(['bed_bath_table'], dtype=object),
#  array(['baby'], dtype=object),
#  array(['sports_leisure'], dtype=object),
#  array(['health_beauty'], dtype=object),
#  array(['computers_accessories'], dtype=object),
#  array(['furniture_decor'], dtype=object),
#  array(['telephony'], dtype=object),
#  array(['health_beauty'], dtype=object),
#  array(['telephony'], dtype=object),
#  array(['furniture_decor'], dtype=object),
#  array(['telephony'], dtype=object),
#  array(['construction_tools_construction'], dtype=object),
#  array(['furniture_decor'], dtype=object),
#  array(['watches_gifts'], dtype=object),
#  array(['health_beauty'], dtype=object),
#  array(['furniture_decor'], dtype=object),
#  array(['stationery'], dtype=object),
#  array(['toys'], dtype=object),
#  array(['luggage_accessories'], dtype=object),
#  array(['computers_accessories'], dtype=object),
#  array(['bed_bath_table'], dtype=object),
#  array(['electronics'], dtype=object),
#  array(['health_beauty'], dtype=object),
#  array(['small_appliances'], dtype=object),
#  array(['pet_shop'], dtype=object),
#  array(['furniture_decor'], dtype=object),
#  array(['telephony'], dtype=object),
#  array(['health_beauty'], dtype=object),
#  array(['office_furniture'], dtype=object),
#  array(['computers_accessories'], dtype=object),
#  array(['garden_tools'], dtype=object),
#  array(['stationery'], dtype=object),
#  array(['watches_gifts'], dtype=object),
#  array(['computers_accessories'], dtype=object),
#  array(['computers_accessories'], dtype=object),
#  array(['health_beauty'], dtype=object),
#  array(['sports_leisure'], dtype=object),
#  array(['furniture_bedroom'], dtype=object),
#  array(['toys'], dtype=object),
#  array(['bed_bath_table'], dtype=object),
#  array(['garden_tools'], dtype=object),
#  array(['housewares'], dtype=object),
#  array(['electronics'], dtype=object),
#  array(['computers_accessories'], dtype=object),
#  array(['perfumery'], dtype=object),
#  array(['electronics'], dtype=object),
#  array(['health_beauty'], dtype=object),
#  array(['fashion_bags_accessories'], dtype=object),
#  array(['cool_stuff'], dtype=object),
#  array(['fashion_bags_accessories'], dtype=object),
#  array(['computers_accessories', 'dvds_blu_ray'], dtype=object),
#  array(['baby', 'health_beauty'], dtype=object),
#  array(['baby'], dtype=object),
#  array(['watches_gifts'], dtype=object),
#  array(['housewares'], dtype=object),
#  array(['cool_stuff'], dtype=object),
#  array(['housewares'], dtype=object),
#  array(['construction_tools_construction'], dtype=object),
#  array(['housewares'], dtype=object),
#  array(['housewares'], dtype=object),
#  array(['auto'], dtype=object),
#  array(['stationery'], dtype=object),
#  array(['furniture_decor'], dtype=object),
#  array(['bed_bath_table'], dtype=object),
#  array(['health_beauty'], dtype=object),
#  array(['perfumery'], dtype=object),
#  array(['home_appliances'], dtype=object),
#  array(['bed_bath_table'], dtype=object),
#  array(['stationery'], dtype=object),
#  array(['health_beauty'], dtype=object),
#  array(['toys'], dtype=object),
#  array(['auto'], dtype=object),
#  array(['garden_tools'], dtype=object),
#  array(['housewares'], dtype=object),
#  array(['sports_leisure'], dtype=object),
#  array(['telephony'], dtype=object),
#  array(['fashion_bags_accessories'], dtype=object),
#  array(['computers_accessories'], dtype=object),
#  array(['housewares'], dtype=object),
#  array(['auto'], dtype=object),
#  array(['computers_accessories'], dtype=object),
#  array(['sports_leisure'], dtype=object),
#  array(['bed_bath_table'], dtype=object),
#  array(['furniture_decor'], dtype=object),
#  array(['bed_bath_table'], dtype=object),
#  array(['garden_tools'], dtype=object),
#  array(['computers_accessories'], dtype=object),
#  array(['watches_gifts'], dtype=object),
#  array(['watches_gifts'], dtype=object),
#  array(['electronics'], dtype=object),
#  array(['telephony'], dtype=object),
#  array(['garden_tools'], dtype=object),
#  array(['sports_leisure'], dtype=object),
#  array(['costruction_tools_tools'], dtype=object),
#  array(['pet_shop'], dtype=object),
#  array(['sports_leisure'], dtype=object),
#  array(['electronics'], dtype=object),
#  array(['cool_stuff'], dtype=object),
#  array(['auto'], dtype=object),
#  array(['stationery'], dtype=object),
#  array(['pet_shop'], dtype=object),
#  array(['health_beauty'], dtype=object),
#  array(['watches_gifts'], dtype=object),
#  array(['pet_shop'], dtype=object),
#  array(['baby'], dtype=object),
#  array(['fashion_sport'], dtype=object),
#  array(['perfumery'], dtype=object),
#  array(['bed_bath_table'], dtype=object),
#  array(['sports_leisure'], dtype=object),
#  ...]

# %%
counts = [len(transaction) for transaction in customer_purchase_pdts_list]
np.median(counts)
# Out:
# 1.0

# %%
np.max(counts)
# Out:
# 5

# %%
from mlxtend.preprocessing import TransactionEncoder
# Instantiate an encoder.
encoder = TransactionEncoder()

# Fit encoder to list of lists.
encoder.fit(customer_purchase_pdts_list)

# Transform lists into one-hot encoded array.
onehot = encoder.transform(customer_purchase_pdts_list)
# Convert array to pandas DataFrame.
onehot = pd.DataFrame(onehot, columns = encoder.columns_)
# Print header.
onehot.head()
# Out:
#    agro_industry_and_commerce  air_conditioning    art  arts_and_craftmanship  \
# 0                       False             False  False                  False
# 1                       False             False  False                  False
# 2                       False             False  False                  False
# 3                       False             False  False                  False
# 4                       False             False  False                  False
#
#    audio   auto   baby  bed_bath_table  books_general_interest  \
# 0  False  False  False            True                   False
# 1  False  False  False           False                   False
# 2  False  False  False           False                   False
# 3  False  False  False           False                   False
# 4  False  False  False           False                   False
#
#    books_imported  ...  security_and_services  signaling_and_security  \
# 0           False  ...                  False                   False
# 1           False  ...                  False                   False
# 2           False  ...                  False                   False
# 3           False  ...                  False                   False
# 4           False  ...                  False                   False
#
#    small_appliances  small_appliances_home_oven_and_coffee  sports_leisure  \
# 0             False                                  False           False
# 1             False                                  False           False
# 2             False                                  False           False
# 3             False                                  False           False
# 4             False                                  False           False
#
#    stationery  tablets_printing_image  telephony   toys  watches_gifts
# 0       False                   False      False  False          False
# 1       False                   False      False  False          False
# 2        True                   False      False  False          False
# 3       False                   False       True  False          False
# 4       False                   False       True  False          False
#
# [5 rows x 71 columns]

# %%
onehot.mean(axis=0)
# Out:
# agro_industry_and_commerce    0.001938
# air_conditioning              0.002645
# art                           0.002141
# arts_and_craftmanship         0.000225
# audio                         0.003705
#                                 ...
# stationery                    0.024412
# tablets_printing_image        0.000824
# telephony                     0.044145
# toys                          0.040804
# watches_gifts                 0.058878
# Length: 71, dtype: float64

# %%
onehot.sum(axis=1).value_counts()
# Out:
# 1    91210
# 2     2062
# 3      108
# 4       12
# 5        5
# dtype: int64

# %%
from mlxtend.frequent_patterns import apriori

#applying the apriori algorithm
frequent_itemsets = apriori(onehot, min_support = 0.001, use_colnames = True)
frequent_itemsets
# Out:
#      support                                   itemsets
# 0   0.001938               (agro_industry_and_commerce)
# 1   0.002645                         (air_conditioning)
# 2   0.002141                                      (art)
# 3   0.003705                                    (audio)
# 4   0.041040                                     (auto)
# 5   0.030354                                     (baby)
# 6   0.096866                           (bed_bath_table)
# 7   0.005375                   (books_general_interest)
# 8   0.002741                          (books_technical)
# 9   0.001349                       (christmas_supplies)
# 10  0.001884                                (computers)
# 11  0.069810                    (computers_accessories)
# 12  0.011221                           (consoles_games)
# 13  0.007912          (construction_tools_construction)
# 14  0.002580                (construction_tools_lights)
# 15  0.001767                (construction_tools_safety)
# 16  0.038352                               (cool_stuff)
# 17  0.002045                 (costruction_tools_garden)
# 18  0.001006                  (costruction_tools_tools)
# 19  0.003116                                   (drinks)
# 20  0.027003                              (electronics)
# 21  0.019165                 (fashion_bags_accessories)
# 22  0.001167                    (fashion_male_clothing)
# 23  0.002505                            (fashion_shoes)
# 24  0.001285                  (fashion_underwear_beach)
# 25  0.002291                          (fixed_telephony)
# 26  0.004722                                     (food)
# 27  0.002398                               (food_drink)
# 28  0.067111                          (furniture_decor)
# 29  0.004390                    (furniture_living_room)
# 30  0.037121                             (garden_tools)
# 31  0.092241                            (health_beauty)
# 32  0.007506                          (home_appliances)
# 33  0.002430                        (home_appliances_2)
# 34  0.004219                             (home_confort)
# 35  0.005204                        (home_construction)
# 36  0.061897                               (housewares)
# 37  0.002473           (industry_commerce_and_business)
# 38  0.002623  (kitchen_dining_laundry_garden_furniture)
# 39  0.010964                      (luggage_accessories)
# 40  0.002966                             (market_place)
# 41  0.006617                      (musical_instruments)
# 42  0.013427                         (office_furniture)
# 43  0.033320                                (perfumery)
# 44  0.017988                                 (pet_shop)
# 45  0.001467                   (signaling_and_security)
# 46  0.006649                         (small_appliances)
# 47  0.079949                           (sports_leisure)
# 48  0.024412                               (stationery)
# 49  0.044145                                (telephony)
# 50  0.040804                                     (toys)
# 51  0.058878                            (watches_gifts)
# 52  0.001638          (furniture_decor, bed_bath_table)

# %%
# Apply apriori algorithm to data with a two-item limit.
frequent_itemsets = apriori(onehot, min_support = 0.00005, max_len = 2, use_colnames = True)
frequent_itemsets
# Out:
#       support                         itemsets
# 0    0.001938     (agro_industry_and_commerce)
# 1    0.002645               (air_conditioning)
# 2    0.002141                            (art)
# 3    0.000225          (arts_and_craftmanship)
# 4    0.003705                          (audio)
# ..        ...                              ...
# 204  0.000214  (sports_leisure, watches_gifts)
# 205  0.000139               (toys, stationery)
# 206  0.000064      (watches_gifts, stationery)
# 207  0.000096       (telephony, watches_gifts)
# 208  0.000107            (toys, watches_gifts)
#
# [209 rows x 2 columns]

# %%
from mlxtend.frequent_patterns import association_rules

# Recover association rules using support and a minimum threshold of 0.0001.
rules = association_rules(frequent_itemsets, metric = 'support', min_threshold = 0.0001)

# Print rules header.
rules
# Out:
#           antecedents       consequents  antecedent support  \
# 0              (auto)  (bed_bath_table)            0.041040
# 1    (bed_bath_table)            (auto)            0.096866
# 2              (auto)    (garden_tools)            0.041040
# 3      (garden_tools)            (auto)            0.037121
# 4              (auto)       (telephony)            0.041040
# ..                ...               ...                 ...
# 129   (watches_gifts)  (sports_leisure)            0.058878
# 130            (toys)      (stationery)            0.040804
# 131      (stationery)            (toys)            0.024412
# 132            (toys)   (watches_gifts)            0.040804
# 133   (watches_gifts)            (toys)            0.058878
#
#      consequent support   support  confidence      lift  leverage  conviction
# 0              0.096866  0.000161    0.003913  0.040400 -0.003815    0.906682
# 1              0.041040  0.000161    0.001658  0.040400 -0.003815    0.960553
# 2              0.037121  0.000118    0.002870  0.077310 -0.001406    0.965650
# 3              0.041040  0.000118    0.003173  0.077310 -0.001406    0.962012
# 4              0.044145  0.000107    0.002609  0.059099 -0.001705    0.958355
# ..                  ...       ...         ...       ...       ...         ...
# 129            0.079949  0.000214    0.003637  0.045492 -0.004493    0.923409
# 130            0.024412  0.000139    0.003411  0.139734 -0.000857    0.978927
# 131            0.040804  0.000139    0.005702  0.139734 -0.000857    0.964696
# 132            0.058878  0.000107    0.002624  0.044567 -0.002295    0.943598
# 133            0.040804  0.000107    0.001819  0.044567 -0.002295    0.960943
#
# [134 rows x 9 columns]

# %%
# Recover association rules using confidence threshold of 0.01.
rules = association_rules(frequent_itemsets, metric = 'confidence', min_threshold = 0.01)

# Print rules.
rules
# Out:
#                                   antecedents         consequents  \
# 0                                       (art)   (furniture_decor)
# 1                                     (audio)     (watches_gifts)
# 2                                      (baby)    (bed_bath_table)
# 3                                      (baby)        (cool_stuff)
# 4                           (furniture_decor)    (bed_bath_table)
# 5                            (bed_bath_table)   (furniture_decor)
# 6                     (furniture_living_room)    (bed_bath_table)
# 7                              (home_confort)    (bed_bath_table)
# 8                                (housewares)    (bed_bath_table)
# 9   (kitchen_dining_laundry_garden_furniture)    (bed_bath_table)
# 10                (construction_tools_lights)   (furniture_decor)
# 11                                   (drinks)     (health_beauty)
# 12                                   (drinks)    (sports_leisure)
# 13                                     (food)     (health_beauty)
# 14                                     (food)         (perfumery)
# 15                                     (food)    (sports_leisure)
# 16                               (food_drink)    (sports_leisure)
# 17                    (furniture_living_room)   (furniture_decor)
# 18                             (garden_tools)   (furniture_decor)
# 19                             (home_confort)   (furniture_decor)
# 20                        (home_construction)   (furniture_decor)
# 21                               (housewares)   (furniture_decor)
# 22  (kitchen_dining_laundry_garden_furniture)   (furniture_decor)
# 23                    (furniture_living_room)  (office_furniture)
# 24                        (home_construction)      (garden_tools)
#
#     antecedent support  consequent support   support  confidence      lift  \
# 0             0.002141            0.067111  0.000054    0.025000  0.372515
# 1             0.003705            0.058878  0.000086    0.023121  0.392702
# 2             0.030354            0.096866  0.000396    0.013051  0.134734
# 3             0.030354            0.038352  0.000332    0.010935  0.285112
# 4             0.067111            0.096866  0.001638    0.024410  0.251994
# 5             0.096866            0.067111  0.001638    0.016912  0.251994
# 6             0.004390            0.096866  0.000096    0.021951  0.226614
# 7             0.004219            0.096866  0.000578    0.137056  1.414900
# 8             0.061897            0.096866  0.000717    0.011590  0.119647
# 9             0.002623            0.096866  0.000054    0.020408  0.210684
# 10            0.002580            0.067111  0.000193    0.074689  1.112908
# 11            0.003116            0.092241  0.000064    0.020619  0.223530
# 12            0.003116            0.079949  0.000054    0.017182  0.214914
# 13            0.004722            0.092241  0.000064    0.013605  0.147499
# 14            0.004722            0.033320  0.000054    0.011338  0.340271
# 15            0.004722            0.079949  0.000064    0.013605  0.170176
# 16            0.002398            0.079949  0.000054    0.022321  0.279196
# 17            0.004390            0.067111  0.000118    0.026829  0.399772
# 18            0.037121            0.067111  0.000493    0.013268  0.197701
# 19            0.004219            0.067111  0.000096    0.022843  0.340369
# 20            0.005204            0.067111  0.000203    0.039095  0.582534
# 21            0.061897            0.067111  0.000642    0.010379  0.154651
# 22            0.002623            0.067111  0.000054    0.020408  0.304094
# 23            0.004390            0.013427  0.000054    0.012195  0.908284
# 24            0.005204            0.037121  0.000107    0.020576  0.554297
#
#     leverage  conviction
# 0  -0.000090    0.956809
# 1  -0.000132    0.963397
# 2  -0.002544    0.915077
# 3  -0.000832    0.972279
# 4  -0.004863    0.925731
# 5  -0.004863    0.948937
# 6  -0.000329    0.923404
# 7   0.000170    1.046573
# 8  -0.005278    0.913724
# 9  -0.000201    0.921949
# 10  0.000020    1.008189
# 11 -0.000223    0.926870
# 12 -0.000196    0.936136
# 13 -0.000371    0.920280
# 14 -0.000104    0.977766
# 15 -0.000313    0.932741
# 16 -0.000138    0.941057
# 17 -0.000177    0.958607
# 18 -0.001999    0.945433
# 19 -0.000187    0.954696
# 20 -0.000146    0.970843
# 21 -0.003512    0.942672
# 22 -0.000123    0.952324
# 23 -0.000005    0.998753
# 24 -0.000086    0.983107

# %%
transactions_df = pd.DataFrame(customer_purchase_pdts_dict.values())
transactions_df
# Out:
#                     0     1     2     3     4
# 0      bed_bath_table  None  None  None  None
# 1       health_beauty  None  None  None  None
# 2          stationery  None  None  None  None
# 3           telephony  None  None  None  None
# 4           telephony  None  None  None  None
# ...               ...   ...   ...   ...   ...
# 93392   health_beauty  None  None  None  None
# 93393            baby  None  None  None  None
# 93394            auto  None  None  None  None
# 93395   watches_gifts  None  None  None  None
# 93396       perfumery  None  None  None  None
#
# [93397 rows x 5 columns]

# %% [markdown]
# **Sort the rules with highest lift**

# %%
# Sort the association rules by lift score
association_results_sorted = rules.sort_values(by='lift', ascending=False)

# %%
# Select the top N rules with highest lift score
N = 10
selected_rules = association_results_sorted.head(N)

# %%
selected_rules
# Out:
#                     antecedents         consequents  antecedent support  \
# 7                (home_confort)    (bed_bath_table)            0.004219
# 10  (construction_tools_lights)   (furniture_decor)            0.002580
# 23      (furniture_living_room)  (office_furniture)            0.004390
# 20          (home_construction)   (furniture_decor)            0.005204
# 24          (home_construction)      (garden_tools)            0.005204
# 17      (furniture_living_room)   (furniture_decor)            0.004390
# 1                       (audio)     (watches_gifts)            0.003705
# 0                         (art)   (furniture_decor)            0.002141
# 19               (home_confort)   (furniture_decor)            0.004219
# 14                       (food)         (perfumery)            0.004722
#
#     consequent support   support  confidence      lift  leverage  conviction
# 7             0.096866  0.000578    0.137056  1.414900  0.000170    1.046573
# 10            0.067111  0.000193    0.074689  1.112908  0.000020    1.008189
# 23            0.013427  0.000054    0.012195  0.908284 -0.000005    0.998753
# 20            0.067111  0.000203    0.039095  0.582534 -0.000146    0.970843
# 24            0.037121  0.000107    0.020576  0.554297 -0.000086    0.983107
# 17            0.067111  0.000118    0.026829  0.399772 -0.000177    0.958607
# 1             0.058878  0.000086    0.023121  0.392702 -0.000132    0.963397
# 0             0.067111  0.000054    0.025000  0.372515 -0.000090    0.956809
# 19            0.067111  0.000096    0.022843  0.340369 -0.000187    0.954696
# 14            0.033320  0.000054    0.011338  0.340271 -0.000104    0.977766

# %%
# Extract the antecedent items from the selected rules
recommendations = []
for antecedents, consequents, confidence, lift in selected_rules[['antecedents', 'consequents', 'confidence', 'lift']].values:
    antecedents = list(antecedents)
    recommendations.extend(antecedents)

# Remove duplicates and convert to a set
recommendations = list(set(recommendations))

# Provide the recommendations for the target item
print("Recommended items:", recommendations)
# Out:
# Recommended items: ['home_construction', 'audio', 'home_confort', 'art', 'construction_tools_lights', 'food', 'furniture_living_room']

# %%
# Plot leverage against confidence.
plt.figure(figsize=(15,5))
sns.scatterplot(x="support", y="confidence", data=rules)
# Out:
# <AxesSubplot: xlabel='support', ylabel='confidence'>
